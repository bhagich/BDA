# %% [markdown]
# <a href="https://www.kaggle.com/code/bhargavichintalapati/ass1-univ-bda-bc?scriptVersionId=105958238" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
print(os.listdir("../input/best-universities-in-the-united-kingdom"))
univ = pd.read_csv('../input/best-universities-in-the-united-kingdom/uk_universities.csv')
# Out:
# ['uk_universities.csv']

# %%
#describe the type of data
univ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 21 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   University_name                                131 non-null    object
#  1   Region                                         131 non-null    object
#  2   Founded_year                                   131 non-null    int64
#  3   Motto                                          114 non-null    object
#  4   UK_rank                                        131 non-null    int64
#  5   World_rank                                     131 non-null    int64
#  6   CWUR_score                                     84 non-null     float64
#  7   Minimum_IELTS_score                            131 non-null    float64
#  8   UG_average_fees_(in_pounds)                    131 non-null    int64
# ...

# %%
#See how the data is
univ.head()
# Out:
#             University_name              Region  Founded_year  \
# 0   University of Cambridge     East of England          1209
# 1      University of Oxford  South East England          1096
# 2  University of St Andrews            Scotland          1413
# 3   Imperial College London              London          1907
# 4   Loughborough University       East Midlands          1966
#
#                                                Motto  UK_rank  World_rank  \
# 0               From here, light and sacred draughts        1           4
# 1                               The Lord is my light        2           2
# 2                                      Ever to excel        3          86
# 3  Knowledge is the adornment and safeguard of th...        4           8
# 4                   With Truth, Knowledge and Labour        5         404
#
#    CWUR_score  Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 0        94.1                  6.5                        21750
# ...

# %%
univ.tail()
# Out:
#                     University_name           Region  Founded_year  \
# 126       University of East London           London          1992
# 127      University of Bedfordshire  East of England          2006
# 128           University of Suffolk  East of England          2007
# 129      Wrexham Glyndwr University            Wales          2008
# 130  Ravensbourne University London           London          1962
#
#                                Motto  UK_rank  World_rank  CWUR_score  \
# 126  Science and fulfillment of vows      127         971         NaN
# 127                              NaN      128        1281         NaN
# 128            Honesty and diligence      129        4030         NaN
# 129     Confidence through Education      130        2397         NaN
# 130            Designed for industry      131        2759         NaN
#
#      Minimum_IELTS_score  UG_average_fees_(in_pounds)  \
# 126                  4.5                        10700
# ...

# %%
#Find the number of rows and columns
univ.shape
# Out:
# (131, 21)

# %%
#Find the name of columns
univ.columns
# Out:
# Index(['University_name', 'Region', 'Founded_year', 'Motto', 'UK_rank',
#        'World_rank', 'CWUR_score', 'Minimum_IELTS_score',
#        'UG_average_fees_(in_pounds)', 'PG_average_fees_(in_pounds)',
#        'International_students', 'Student_satisfaction', 'Student_enrollment',
#        'Academic_staff', 'Control_type', 'Academic_Calender', 'Campus_setting',
#        'Estimated_cost_of_living_per_year_(in_pounds)', 'Latitude',
#        'Longitude', 'Website'],
#       dtype='object')

# %%
univ['Estimated_cost_of_living_per_year_(in_pounds)'].head()
# Out:
# 0    12000
# 1    11500
# 2    12000
# 3    10700
# 4     9398
# Name: Estimated_cost_of_living_per_year_(in_pounds), dtype: int64

# %%
#find the statistcs of cost of living
univ['Estimated_cost_of_living_per_year_(in_pounds)'].describe()
# Out:
# count      131.000000
# mean      8644.732824
# std       1579.049538
# min       5500.000000
# 25%       7710.500000
# 50%       8217.000000
# 75%       9457.500000
# max      15000.000000
# Name: Estimated_cost_of_living_per_year_(in_pounds), dtype: float64

# %%
#skewness and kurtosis
print("Skewness: %f" % univ['Estimated_cost_of_living_per_year_(in_pounds)'].skew())
print("Kurtosis: %f" % univ['Estimated_cost_of_living_per_year_(in_pounds)'].kurt())
# Out:
# Skewness: 0.833136
# Kurtosis: 1.414433

# %%
calendar_type = univ['Academic_Calender'].astype('category') #changes the type of column from object to category
calendar_type.head()
# Out:
# 0    Trimesters
# 1    Trimesters
# 2     Semesters
# 3    Continuous
# 4     Semesters
# Name: Academic_Calender, dtype: category
# Categories (5, object): ['Continuous', 'Other', 'Quarters', 'Semesters', 'Trimesters']

# %%
control_type = univ['Control_type'].astype('category') #changes the type of column from object to category
control_type.head()
# Out:
# 0    Public
# 1    Public
# 2    Public
# 3    Public
# 4    Public
# Name: Control_type, dtype: category
# Categories (2, object): ['Private', 'Public']

# %%
campus_at = univ['Campus_setting'].astype('category')#changes the type of column from object to category
campus_at.head()
# Out:
# 0       Urban
# 1       Urban
# 2    Suburban
# 3       Urban
# 4    Suburban
# Name: Campus_setting, dtype: category
# Categories (3, object): ['Rural', 'Suburban', 'Urban']

# %%
region = univ['Region'].astype('category')
region.head()
# Out:
# 0       East of England
# 1    South East England
# 2              Scotland
# 3                London
# 4         East Midlands
# Name: Region, dtype: category
# Categories (12, object): ['East Midlands', 'East of England', 'London', 'North East England', ..., 'South West England', 'Wales', 'West Midlands', 'Yorkshire and the Humber']

# %%
region.value_counts()
# Out:
# London                      22
# South East England          17
# Scotland                    14
# South West England          12
# North West England          11
# Yorkshire and the Humber    11
# East of England             10
# West Midlands               10
# Wales                        9
# East Midlands                7
# North East England           6
# Northern Ireland             2
# Name: Region, dtype: int64

# %%
calendar_type.describe()
# Out:
# count           105
# unique            5
# top       Semesters
# freq             75
# Name: Academic_Calender, dtype: object

# %%
column = calendar_type
print('Column Name:{}\nCardinality:{}\nValues:{}'.format(column.name,column.nunique(), column.unique()))
# Out:
# Column Name:Academic_Calender
# Cardinality:5
# Values:['Trimesters', 'Semesters', 'Continuous', 'Other', NaN, 'Quarters']
# Categories (5, object): ['Continuous', 'Other', 'Quarters', 'Semesters', 'Trimesters']

# %%
calendar_type.value_counts()
# Out:
# Semesters     75
# Trimesters    15
# Continuous     7
# Other          7
# Quarters       1
# Name: Academic_Calender, dtype: int64

# %%
#from above, we understood, we can change the datatypes of the columns. Lets change and find the difference
univ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 21 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   University_name                                131 non-null    object
#  1   Region                                         131 non-null    object
#  2   Founded_year                                   131 non-null    int64
#  3   Motto                                          114 non-null    object
#  4   UK_rank                                        131 non-null    int64
#  5   World_rank                                     131 non-null    int64
#  6   CWUR_score                                     84 non-null     float64
#  7   Minimum_IELTS_score                            131 non-null    float64
#  8   UG_average_fees_(in_pounds)                    131 non-null    int64
# ...

# %%
univ = univ.astype({'Academic_Calender':'category','Control_type':'category','Region':'category','Campus_setting':'category'})
univ.info()
#if you see, the size of the dataframe is reduced when you categorise the right datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 21 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   University_name                                131 non-null    object
#  1   Region                                         131 non-null    category
#  2   Founded_year                                   131 non-null    int64
#  3   Motto                                          114 non-null    object
#  4   UK_rank                                        131 non-null    int64
#  5   World_rank                                     131 non-null    int64
#  6   CWUR_score                                     84 non-null     float64
#  7   Minimum_IELTS_score                            131 non-null    float64
#  8   UG_average_fees_(in_pounds)                    131 non-null    int64
# ...

# %%
print('Column Name:{}\nCardinality:{}\nValues:{}'.format(univ['University_name'].name,univ['University_name'].nunique(), univ['University_name'].unique()))
# Out:
# Column Name:University_name
# Cardinality:131
# Values:['University of Cambridge' 'University of Oxford'
#  'University of St Andrews' 'Imperial College London'
#  'Loughborough University'
#  'London School of Economics and Political Science' 'Durham University'
#  'Lancaster University' 'University College London'
#  'University of Warwick' 'University of Bath' 'University of Exeter'
#  'University of Leeds' 'University of Birmingham' 'University of Bristol'
#  'University of Glasgow' 'Harper Adams University'
#  'University of Manchester' 'Royal Holloway, University of London'
#  'University of Southampton' 'University of Nottingham'
#  'University of York' 'University of East Anglia UEA'
#  'University of Dundee' 'University of Edinburgh'
#  'University of Sheffield' 'University of Aberdeen' 'Newcastle University'
#  'University of Liverpool' "King's College London" 'Swansea University'
#  'University of Surrey' 'Heriot-Watt University' 'Cardiff University'
# ...

# %%
#As you can see there are unique values on university name. we can make this as index.
univ.set_index('University_name',inplace=True)
univ.head()
# Out:
#                                       Region  Founded_year  \
# University_name
# University of Cambridge      East of England          1209
# University of Oxford      South East England          1096
# University of St Andrews            Scotland          1413
# Imperial College London               London          1907
# Loughborough University        East Midlands          1966
#
#                                                                       Motto  \
# University_name
# University of Cambridge                From here, light and sacred draughts
# University of Oxford                                   The Lord is my light
# University of St Andrews                                      Ever to excel
# Imperial College London   Knowledge is the adornment and safeguard of th...
# Loughborough University                    With Truth, Knowledge and Labour
#
#                           UK_rank  World_rank  CWUR_score  \
# University_name
# ...

# %%
#The 5 top UK universities wrt World Rank
univ.nsmallest(5,['World_rank','UK_rank'])[['Founded_year','UK_rank','World_rank','Minimum_IELTS_score','PG_average_fees_(in_pounds)','Estimated_cost_of_living_per_year_(in_pounds)','Control_type','Academic_Calender','Website']]
# Out:
#                                                   Founded_year  UK_rank  \
# University_name
# University of Oxford                                      1096        2
# University of Cambridge                                   1209        1
# Imperial College London                                   1907        4
# University College London                                 1826        9
# London School of Economics and Political Science          1895        6
#
#                                                   World_rank  \
# University_name
# University of Oxford                                       2
# University of Cambridge                                    4
# Imperial College London                                    8
# University College London                                 14
# London School of Economics and Political Science          23
#
#                                                   Minimum_IELTS_score  \
# University_name
# ...

# %%
#Total number of universities per region
univ['Region'].value_counts().plot(kind="pie")
plt.show()

# %%
#Number of colleges founded in a given year
sns.displot(univ.Founded_year)

# %%
#Use subplots to plot different parameters on same page

columns = ['Estimated_cost_of_living_per_year_(in_pounds)', 'Minimum_IELTS_score', 'UG_average_fees_(in_pounds)', 'PG_average_fees_(in_pounds)']
fig,ax = plt.subplots(2,2, figsize = (10,10))
ax = ax.flatten()
for i in range(len(columns)):
    sns.histplot(univ[columns[i]],ax = ax[i])

# %%
#Difference between histplot and displot
sns.histplot(univ["PG_average_fees_(in_pounds)"])
sns.displot(data=univ, x = "PG_average_fees_(in_pounds)",kde=True)

# %%
univ.groupby(['Region']).mean()[['UG_average_fees_(in_pounds)','PG_average_fees_(in_pounds)','Minimum_IELTS_score','Estimated_cost_of_living_per_year_(in_pounds)']]
# Out:
#                           UG_average_fees_(in_pounds)  \
# Region
# East Midlands                            12864.714286
# East of England                          12449.500000
# London                                   13498.636364
# North East England                       11555.000000
# North West England                       12003.181818
# Northern Ireland                         12887.500000
# Scotland                                 12571.571429
# South East England                       13096.470588
# South West England                       12337.500000
# Wales                                    11161.111111
# West Midlands                            12206.600000
# Yorkshire and the Humber                 12230.909091
#
#                           PG_average_fees_(in_pounds)  Minimum_IELTS_score  \
# Region
# East Midlands                            12968.142857             4.714286
# East of England                          12843.200000             4.900000
# ...

# %%
#Map Avg IELTS Score, UG fee, PG Fee, Costof Living wrt Region
df = univ.groupby(['Region']).mean()[['UG_average_fees_(in_pounds)','PG_average_fees_(in_pounds)','Estimated_cost_of_living_per_year_(in_pounds)']]
df.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
#Map Avg IELTS Score, UG fee, PG Fee, Costof Living wrt Campus setting
univ.groupby(['Region','Campus_setting']).mean()[['UG_average_fees_(in_pounds)','PG_average_fees_(in_pounds)','Estimated_cost_of_living_per_year_(in_pounds)']]
# Out:
#                                          UG_average_fees_(in_pounds)  \
# Region                   Campus_setting
# East Midlands            Rural                                   NaN
#                          Suburban                       13810.000000
#                          Urban                          11531.500000
# East of England          Rural                                   NaN
#                          Suburban                       12566.666667
#                          Urban                          12883.333333
# London                   Rural                                   NaN
#                          Suburban                       11512.500000
#                          Urban                          14208.000000
# North East England       Rural                          11150.000000
#                          Suburban                                NaN
#                          Urban                          11636.000000
# ...

# %%
def getCorrHeatMap(dataFrame,figSize=[12,9]):
    corrmat = dataFrame.corr()
    f, ax = plt.subplots(figsize=(figSize[0], figSize[1]))
    sns.heatmap(corrmat);

getCorrHeatMap(univ)

# %%
def getZoomedCorrHeatMap(dataFrame,featureCount,target,figSize=[12,9]):
    corrmat = dataFrame.corr()
    cols = corrmat.nlargest(featureCount, target)[target].index
    f , ax = plt.subplots(figsize = (figSize[0],figSize[1]))
    cm = np.corrcoef(dataFrame[cols].values.T)
    sns.set(font_scale=1)
    hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
    plt.show()

getZoomedCorrHeatMap(univ,10,'Estimated_cost_of_living_per_year_(in_pounds)',[8,8])

# %%
def getMissingValuesInfo(df):
    total = df.isnull().sum().sort_values(ascending = False)
    percent = round(df.isnull().sum().sort_values(ascending = False)/len(df)*100, 2)
    temp = pd.concat([total, percent], axis = 1,keys= ['Total Missing Count', '% of Total Observations'])
    temp.index.name ='Feature Name'
    return temp.loc[(temp['Total Missing Count'] > 0)]

getMissingValuesInfo(univ)
# Out:
#                    Total Missing Count  % of Total Observations
# Feature Name
# CWUR_score                          47                    35.88
# Academic_Calender                   26                    19.85
# Campus_setting                      18                    13.74
# Motto                               17                    12.98

# %%
#number of missing values in dataframe wrt column names
missing = univ.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
plt.subplots(figsize=(8,6))
missing.plot.bar()
plt.show()

# %%
#Heatmap wrt null values
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(univ.isnull(), cbar=False, cmap="YlGnBu_r")
plt.show()

# %%
categorical_features = univ.select_dtypes(include='object')
categorical_features.describe()
# Out:
#                                Motto International_students  \
# count                            114                    131
# unique                           113                    107
# top     To know the causes of things                 15.59%
# freq                               2                      7
#
#        Student_satisfaction Student_enrollment Academic_staff        Website
# count                   131                131            131            131
# unique                   82                 16             18            131
# top                  79.00%      15,000-19,999    1,000-1,499  www.cam.ac.uk
# freq                      5                 29             27              1

# %%
#Print the unique values of dataframe which are less than 100 for all the object datatypes
def printUniqueValues(df,cardinality=1000):
    n = df.select_dtypes(include=object)
    for column in n.columns:
        uCount = df[column].nunique()
        if uCount<=cardinality:
            print('{:>12}: {} {}'.format(column,uCount, df[column].unique()))
            #print(column,': [',uCount , '] ', df[column].unique())


printUniqueValues(univ,10)

# %%
#Print the unique values of dataframe for all the object datatypes
def printUniqueValues(df):
    n = df.select_dtypes(include=object)
    for column in n.columns:
        uCount = df[column].nunique()
        print('{:>12}: {} {}'.format(column,uCount, df[column].unique()))
       # print(column,': [',uCount , '] ', df[column].unique())


printUniqueValues(univ)
# Out:
#        Motto: 113 ['From here, light and sacred draughts' 'The Lord is my light'
#  'Ever to excel' 'Knowledge is the adornment and safeguard of the Empire'
#  'With Truth, Knowledge and Labour' 'To know the causes of things'
#  'Her foundations are upon the holy hills' 'Truth lies open to all'
#  'Let all come who by merit most deserve reward' 'Mind Moves matter'
#  'Learn each field of study according to its kind' 'We follow the light'
#  'And Knowledge Will Be Increased'
#  'Through hard work, great heights are achieved'
#  "Learning promotes one's innate power" 'The Way, the Truth and the Life'
#  'Useful and agreeable' 'Knowledge, wisdom, humanity'
#  'To be, rather than to seem' 'The Heights Yield to Endeavour'
#  'A city is built on wisdom' 'On the threshold of wisdom' 'Do different'
#  'My soul magnifies the Lord' 'Seek and You Shall Find'
#  'The fear of the Lord is the beginning of wisdom' 'I look ahead'
#  'These days of peace foster learning' 'With Holiness and Wisdom'
# ...
